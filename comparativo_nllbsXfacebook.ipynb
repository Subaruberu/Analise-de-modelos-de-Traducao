2. Cfr. Jo. 14,26; 16,13,
3. Cfr. Jo. 2,22; 12,16; de acordo com 14,26; 16, 12-13; 7,39.
4. Cfr. Instrução Sancta Mater Ecclesia, da Pontificia Comissão Bíblica: AAS 56 (1964) 715.
Capítulo VI
Pontificia Comissão Bíblica,
1. Cfr. Pio XII, Enc. Divino afflante, 30. set. 1943: EB 551, 553, 567.
 Instructio de S. Scriptura in Clericorum seminariis et Religiosorum Collegiis recte docenda, 13 maio
 1950: AAS 42 (1950) 495-505.
2. Cfr. Pio XII, 1. c.: EB 569.
about:blank
9/10

--- PAGE 10 ---

17/11/2025, 10:30
about:blank
3. Cfr. Leão XIII, Enc. Providentissimus Deus: EB 114; Bento XV, Enc., Spiritus Paraclitus, 15. set.
 1920: EB 483.
4. S. Agostinho, Serm. 179, 1: PL 38, 966.
5. S. Jerónimo, Comm. in Is. Prol.: PL 24, 17. Cfr. Bento XV, Enc. Spiritus Paraclitus: EB 475-480;
Pio XII, Enc. Divino afflante: EB 544.
6. S. Ambrósio, De officiis ministrorum I, 20, 88: PL 16, 50.
7. S. Ireneu, Adv. Haer. IV, 32, 1: PG 7, 1071; $(=49,2)$, Harvey, 2, p. 255.
about:blank
10/10
"""

def limpar_e_extrair_texto(conteudo_pdf):
    """
    Limpa marcas de fonte, cabeçalhos de página e quebras de página
    de um texto extraído de PDF para obter o conteúdo principal.
    """
    # 1. Remover marcas de fonte e URLs irrelevantes (Ex: , about:blank)
    texto_limpo = re.sub(r"'", '', conteudo_pdf) # Corrigido: remover aspas simples
    texto_limpo = re.sub(r'about:blank', '', texto_limpo)
    texto_limpo = re.sub(r'\s{1,}f\s{1,}', ' ', texto_limpo) # Remove 'f' solto
    texto_limpo = re.sub(r'↑', '', texto_limpo) # Remover o caractere '↑'
    texto_limpo = re.sub(r'\[AR-BE-CS-DE-EN-ES-FR-IT-HE-HU-LA-LV-PT-SW-ZH\]', '', texto_limpo)

    # 2. Remover cabeçalhos e rodapés de paginação (Ex: 17/11/2025, 10:30, 1/10)
    texto_limpo = re.sub(r'\d{1,2}/\d{1,2}/\d{4}, \d{1,2}:\d{2}', '', texto_limpo)
    texto_limpo = re.sub(r'\d{1,2}/\d{1,2}\n', '', texto_limpo)

    # 3. Remover os separadores de página criados pelo extrator/sistema
    texto_limpo = re.sub(r'---\s+PAGE\s+\d+\s+---', '', texto_limpo)

    # 4. Remover a seção de NOTAS (e tudo que vier depois dela), que é separada do texto principal
    # Esta seção começa com o título 'Notas' [cite: 203]
    texto_principal = texto_limpo.split('Notas\n')[0]

    # 5. Normalizar espaços múltiplos e quebras de linha para organizar parágrafos
    texto_principal = re.sub(r'\n\s*\n', '\n\n', texto_principal).strip()

    return texto_principal

def gerar_arquivo(texto, nome_arquivo='dei_verbum_pdf_extraido.txt'):
    """Salva o texto limpo em um arquivo."""
    try:
        with open(nome_arquivo, 'w', encoding='utf-8') as f:
            f.write(texto)

        tamanho = os.path.getsize(nome_arquivo) / 1024 # Tamanho em KB
        print(f"✅ **Sucesso!** O texto principal (limpo) foi salvo em: `{nome_arquivo}`")
        print(f"   Tamanho aproximado do arquivo: {tamanho:.2f} KB.")
        print("\n--- INÍCIO DO ARQUIVO GERADO (Prévia) ---")
        print(texto[:500] + "\n...") # Imprime as 500 primeiras letras
        print("------------------------------------------")

    except IOError as e:
        print(f"\n❌ Erro ao salvar o arquivo: {e}")

# --- EXECUÇÃO ---
texto_extraido_limpo = limpar_e_extrair_texto(pdf_content)
gerar_arquivo(texto_extraido_limpo)
# Out:
# ✅ **Sucesso!** O texto principal (limpo) foi salvo em: `dei_verbum_pdf_extraido.txt`
#    Tamanho aproximado do arquivo: 28.38 KB.
#
# --- INÍCIO DO ARQUIVO GERADO (Prévia) ---
# CONSTITUIÇÃO DOGMÁTICA
# DEI VERBUM
#  SOBRE A REVELAÇÃO DIVINA
# PROÉMIO
# Intenção do Concílio
# 1. O sagrado Concilio, ouvindo religiosamente a Palavra de Deus proclamando-a com confiança, faz suas
#  as palavras de S. João: «anunciamo-vos a vida eterna, que estava junto do Pai e nos apareceu: anunciamo-
#  vos o que vimos e ouvimos, para que também vós vivais em comunhão connosco, e a nossa comunhão
#  seja com o Pai e com o seu Filho Jesus Cristo" (1 Jo. 1, 2-3). Por isso, segundo os Concílios Tridentino e
# ...
# ------------------------------------------

# %%
print(texto_extraido_limpo)
# Out:
# CONSTITUIÇÃO DOGMÁTICA
# DEI VERBUM
#  SOBRE A REVELAÇÃO DIVINA
# PROÉMIO
# Intenção do Concílio
# 1. O sagrado Concilio, ouvindo religiosamente a Palavra de Deus proclamando-a com confiança, faz suas
#  as palavras de S. João: «anunciamo-vos a vida eterna, que estava junto do Pai e nos apareceu: anunciamo-
#  vos o que vimos e ouvimos, para que também vós vivais em comunhão connosco, e a nossa comunhão
#  seja com o Pai e com o seu Filho Jesus Cristo" (1 Jo. 1, 2-3). Por isso, segundo os Concílios Tridentino e
#  Vaticano I, entende propor a genuína doutrina sobre a Revelação divina e a sua transmissão, para que o
#  mundo inteiro, ouvindo, acredite na mensagem da salvação, acreditando
# espere, e esperando ame (1).
# Natureza e objecto da revelação
# CAPÍTULO I
# A REVELAÇÃO EM SI MESMA
# 2. Aprouve a Deus. na sua bondade e sabedoria, revelar-se a Si mesmo e dar a conhecer o mistério da sua
# ...

# %% [markdown]
# ## parte de teste ##

# %%
# --- I. DADOS DE REFERÊNCIA DIVIDIDOS POR PARÁGRAFO (Sentença) ---
import re
from difflib import SequenceMatcher

TEXTO_ITALIANO = (
    "In religioso ascolto della parola di Dio e proclamandola con ferma fiducia, il santo Concilio fa sue "
    "queste parole di san Giovanni: « Annunziamo a voi la vita eterna, che era presso il Padre e si manifestò "
    "a noi: vi annunziamo ciò che abbiamo veduto e udito, affinché anche voi siate in comunione con noi, "
    "e la nostra comunione sia col Padre e col Figlio suo Gesù Cristo » (1 Gv 1,2-3). Perciò seguendo le orme "
    "dei Concili Tridentino e Vaticano I, intende proporre la genuina dottrina sulla divina Rivelazione e la "
    "sua trasmissione, affinché per l'annunzio della salvezza il mondo intero ascoltando creda, credendo speri, "
    "sperando ami."
)

REFERENCIA_PORTUGUES_PARAGRAFOS = [
    "O sagrado Concilio, ouvindo religiosamente a Palavra de Deus proclamando-a com confiança, faz suas as palavras de S. João: «anunciamo-vos a vida eterna, que estava junto do Pai e nos apareceu: anunciamo-vos o que vimos e ouvimos, para que também vós vivais em comunhão connosco, e a nossa comunhão seja com o Pai e com o seu Filho Jesus Cristo» (1 Jo. 1, 2-3).",
    "Por isso, segundo os Concílios Tridentino e Vaticano I, entende propor a genuína doutrina sobre a Revelação divina e a sua transmissão, para que o mundo inteiro, ouvindo, acredite na mensagem da salvação, acreditando espere, e esperando ame."
]

SIMULACAO_TRADUCAO_AUTOMATICA = [
    "O sacro Concílio, ouvindo religiosamente a Palavra de Deus e proclamando-a com firme confiança, faz suas estas palavras de São João: «Anunciamos-vos a vida eterna, que estava junto do Pai e se manifestou a nós: anunciamos-vos o que vimos e ouvimos, a fim de que também vós sejais in comunhão conosco, e a nossa comunhão seja com o Pai e com o seu Filho Jesus Cristo» (1 Jo 1,2-3).",
    "Por isso, seguindo os Concílios Tridentino e Vaticano I, tenciona propor a genuína doutrina sobre a Revelação divina e a sua transmissão, para que, o mundo inteiro, ouvindo, acredite na mensagem da salvação, acreditando espere e esperando ame."
]

def analisar_palavras_para_grafico(candidata, referencia):
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())
    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal':
            contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace':
            contadores["ERRO (Substituição)"] += (i2 - i1)
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert':
            contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete':
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# %% [markdown]
# ## modelo nllb ##

# %%
# --- Ajuste automático: fixar o modelo de tradução para m2m100 (facebook/m2m100_418M)
MODEL_NAME = 'facebook/m2m100_418M'

# %%
from difflib import SequenceMatcher
import re
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import sacrebleu
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# %%
pip install sacrebleu

# %%
# O modelo 'distilled-600M' (ou 3.3B) geralmente funciona melhor com códigos genéricos
model_name = "facebook/m2m100_418M"

# 1. Carregar o Tokenizer e o Modelo
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# 2. Criar o Pipeline de Tradução com o Código Ajustado
translator = pipeline(
    'translation',
    model=model,
    tokenizer=tokenizer,
    # Idioma de Origem: Italiano
    src_lang="it", # Corrigido para 'it'
    tgt_lang="pt" # Corrigido para 'pt'
)

# 3. Texto em Italiano
texto_italiano = "La vita è bella, specialmente quando si mangia bene."

# 4. Realizar a Tradução
resultado = translator(texto_italiano)

# 5. Imprimir o Resultado
traducao_portugues = resultado[0]['translation_text']

print(f"Texto Original (ITA): {texto_italiano}")
print(f"Tradução (POR-Latn): {traducao_portugues}")
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# Device set to use cpu
# Texto Original (ITA): La vita è bella, specialmente quando si mangia bene.
# Tradução (POR-Latn): A vida é boa, especialmente quando você come bem.

# %%
candidatas = [
    """LA RIVELAZIONE

Natura e oggetto della Rivelazione

2. Piacque a Dio nella sua bontà e sapienza rivelarsi in persona e manifestare il mistero della sua volontà (cfr. Ef 1,9), mediante il quale gli uomini per mezzo di Cristo, Verbo fatto carne, hanno accesso al Padre nello Spirito Santo e sono resi partecipi della divina natura (cfr. Ef 2,18; 2 Pt 1,4). Con questa Rivelazione infatti Dio invisibile (cfr. Col 1,15; 1 Tm 1,17) nel suo grande amore parla agli uomini come ad amici (cfr. Es 33,11; Gv 15,14-15) e si intrattiene con essi (cfr. Bar 3,38), per invitarli e ammetterli alla comunione con sé. Questa economia della Rivelazione comprende eventi e parole intimamente connessi, in modo che le opere, compiute da Dio nella storia della salvezza, manifestano e rafforzano la dottrina e le realtà significate dalle parole, mentre le parole proclamano le opere e illustrano il mistero in esse contenuto. La profonda verità, poi, che questa Rivelazione manifesta su Dio e sulla salvezza degli uomini, risplende per noi in Cristo, il quale è insieme il mediatore e la pienezza di tutta intera la Rivelazione [2]..""",
]
referencias_simples = [
    "A vida é como uma caixa de chocolates, você nunca sabe o que vai receber.",
]

resultado_bleu = sacrebleu.corpus_bleu(candidatas, [referencias_simples])

# A Precisão de Unigramas (1-gram) é o primeiro elemento da lista 'precisions'
precisao_palavras = resultado_bleu.precisions[0]

print(f"Precisão de Palavras (Unigramas): {precisao_palavras:.2f}%")
print(f"Isso significa que {precisao_palavras:.2f}% das palavras na tradução")
print(f"gerada também aparecem nas palavras da tradução de referência.")
# Out:
# Precisão de Palavras (Unigramas): 0.89%
# Isso significa que 0.89% das palavras na tradução
# gerada também aparecem nas palavras da tradução de referência.

# %%
def analisar_palavras(candidata, referencia):
    # Remove pontuação e converte para minúsculas
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    output = []

    # Usa SequenceMatcher para encontrar a melhor correspondência de palavras
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    # Itera sobre os "blocos" de correspondência (palavras em comum)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal':
            # Palavras corretas
            for word in candidata_limpa[i1:i2]:
                output.append(f"**{word}** (ACERTO)")
        elif tag == 'replace':
            # Palavras diferentes
            for word in candidata_limpa[i1:i2]:
                output.append(f"*{word}* (ERRO)")
        elif tag == 'delete':
            # Palavras extras na candidata que não estão na referência
            for word in candidata_limpa[i1:i2]:
                output.append(f"~~{word}~~ (EXTRA)")

    return " ".join(output)

# --- Exemplo de Análise ---
candidata = "La vita è bella, specialmente quando si mangia bene."
referencia = "A vida é como uma caixa de chocolates, você nunca sabe o que vai receber."

print(f"Candidata: {candidata}")
print(f"Referência: {referencia}")
print("\n--- ANÁLISE PALAVRA POR PALAVRA (Comparação) ---")

resultado_analise = analisar_palavras(candidata, referencia)
print(resultado_analise)

print("\nLegenda:")
print("* **Negrito:** Palavra correta (presente na referência)")
print("* *Itálico:* Palavra incorreta/diferente (substituição)")
print("* ~~Tachado:~~ Palavra extra (remoção)")
# Out:
# Candidata: La vita è bella, specialmente quando si mangia bene.
# Referência: A vida é como uma caixa de chocolates, você nunca sabe o que vai receber.
#
# --- ANÁLISE PALAVRA POR PALAVRA (Comparação) ---
# *la* (ERRO) *vita* (ERRO) *è* (ERRO) *bella* (ERRO) *specialmente* (ERRO) *quando* (ERRO) *si* (ERRO) *mangia* (ERRO) *bene* (ERRO)
#
# Legenda:
# * **Negrito:** Palavra correta (presente na referência)
# * *Itálico:* Palavra incorreta/diferente (substituição)
# * ~~Tachado:~~ Palavra extra (remoção)

# %%
# Função para comparar e categorizar palavras
def analisar_palavras_para_grafico(candidata, referencia):
    # Remove pontuação e converte para minúsculas
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    # Inicializa contadores
    contadores = {"ACERTO": 0, "ERRO": 0, "EXTRA": 0}

    # Usa SequenceMatcher para encontrar a melhor correspondência de palavras
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    # Itera sobre os "blocos" de correspondência (acertos, substituições, adições)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal':
            # Palavras corretas
            contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace':
            # Palavras diferentes (ERRO na substituição)
            contadores["ERRO"] += (i2 - i1)
        elif tag == 'delete':
            # Palavras extras na candidata (EXTRA)
            contadores["EXTRA"] += (i2 - i1)

    return contadores

# --- Dados de Exemplo ---
candidata = "A vida é como uma caixa de chocolates, nunca se sabe o que vai receber."
referencia = "A vida é como uma caixa de chocolates, você nunca sabe o que vai receber."

# 1. Obter os Contadores
contadores = analisar_palavras_para_grafico(candidata, referencia)

# 2. Preparação dos Dados para o Gráfico
categorias = list(contadores.keys())
valores = list(contadores.values())
cores = ['#4CAF50', '#F44336', '#FF9800']

# 3. Geração do Gráfico
plt.figure(figsize=(8, 5))
barras = plt.bar(categorias, valores, color=cores)

# Títulos e Rótulos
plt.title('Análise de Concordância Palavra por Palavra', fontsize=14)
plt.xlabel('Status da Palavra na Tradução Candidata', fontsize=12)
plt.ylabel('Contagem de Palavras', fontsize=12)

# Adiciona o valor exato no topo de cada barra
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## modelo treinado NLLB ##

# %%
# A tradução gerada (simulando a saída do NLLB-200)
candidatas = [
    """A REVELAÇÃO.Piacque a Dio nella sua bontà e sapienza rivelarsi in persona e manifestare il mistero della sua volontà (cfr. Ef 1,9), mediante il quale gli uomini per mezzo di Cristo, Verbo fatto carne, hanno accesso al Padre nello Spirito Santo e sono resi partecipi della divina natura (cfr. Ef 2,18; 2 Pt 1,4). Con questa Rivelazione infatti Dio invisibile (cfr. Col 1,15; 1 Tm 1,17) nel suo grande amore parla agli uomini come ad amici (cfr. Es 33,11; Gv 15,14-15) e si intrattiene con essi (cfr. Bar 3,38), per invitarli e ammetterli alla comunione con sé. Questa economia della Rivelazione comprende eventi e parole intimamente connessi, in modo che le opere, compiute da Dio nella storia della salvezza, manifestano e rafforzano la dottrina e le realtà significate dalle parole, mentre le parole proclamano le opere e illustrano il mistero in esse contenuto. La profonda verità, poi, che questa Rivelazione manifesta su Dio e sulla salvezza degli uomini, risplende per noi in Cristo, il quale è insieme il mediatore e la pienezza di tutta intera la Rivelazione"""
]

# A tradução oficial e canónica do Vaticano (Referência Humana)
referencias_simples = [
    """A REVELAÇÃO. Natureza e Objecto da Revelação. 2. Aprouve a Deus, na sua bondade e sabedoria, revelar-se a Si próprio e dar a conhecer o mistério da sua vontade (cf. Ef 1, 9), segundo o qual os homens, por meio de Cristo, Verbo encarnado, têm acesso ao Pai no Espírito Santo e se tornam participantes da natureza divina (cf. Ef 2, 18; 2 Pe 1, 4). Por esta revelação, Deus invisível (cf. Col 1, 15; 1 Tim 1, 17), levado pelo seu grande amor, fala aos homens como amigos (cf. Ex 33, 11; Jo 15, 14-15) e convive com eles (cf. Bar 3, 38), para os convidar e admitir à comunhão com Ele. Esta economia da Revelação realiza-se por meio de ações e palavras intimamente conexas, de tal maneira que as obras, realizadas por Deus na história da salvação, manifestam e confirmam a doutrina e as realidades significadas pelas palavras, e as palavras, por sua vez, proclamam as obras e esclarecem o mistério nelas contido. A verdade profunda tanto a respeito de Deus como a respeito da salvação humana, manifesta-se-nos por esta Revelação em Cristo, que é, simultaneamente, o mediador e a plenitude de toda a Revelação [2]."""
]

# -------------------------------------------------------------
# CÁLCULO
# -------------------------------------------------------------
resultado_bleu = sacrebleu.corpus_bleu(candidatas, [referencias_simples])

# A Precisão de Unigramas (1-gram) é o primeiro elemento
precisao_palavras = resultado_bleu.precisions[0]

# -------------------------------------------------------------
# SAÍDA
# -------------------------------------------------------------
print("--- RESULTADO DO SCORE BLEU PARA O PARÁGRAFO 2 DA DEI VERBUM ---")
print(f"Score BLEU (Geral): {resultado_bleu.score:.2f}")
print(f"Detalhes do Score: {resultado_bleu.format()}")
print("\n--- ANÁLISE POR PALAVRAS (UNIGRAMAS) ---")
print(f"Precisão de Palavras (Unigramas): {precisao_palavras:.2f}%")
print(f"Isso significa que {precisao_palavras:.2f}% das palavras na tradução automática")
print(f"também aparecem nas palavras da tradução oficial de referência.")
# Out:
# --- RESULTADO DO SCORE BLEU PARA O PARÁGRAFO 2 DA DEI VERBUM ---
# Score BLEU (Geral): 3.24
# Detalhes do Score: BLEU = 3.24 31.3/8.5/1.9/0.5 (BP = 0.826 ratio = 0.839 hyp_len = 214 ref_len = 255)
#
# --- ANÁLISE POR PALAVRAS (UNIGRAMAS) ---
# Precisão de Palavras (Unigramas): 31.31%
# Isso significa que 31.31% das palavras na tradução automática
# também aparecem nas palavras da tradução oficial de referência.

# %% [markdown]
# ---------------------------------------------------

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline

# O modelo 'distilled-600M' (ou 3.3B) geralmente funciona melhor com códigos genéricos
model_name = "facebook/m2m100_418M"

# 1. Carregar o Tokenizer e o Modelo
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# 2. Criar o Pipeline de Tradução com o Código Ajustado
translator = pipeline(
    'translation',
    model=model,
    tokenizer=tokenizer,
    # Idioma de Origem: Italiano
    src_lang="it", # Corrigido para 'it'
    # MUDANÇA AQUI: Tente o código genérico 'por_Latn' para Português
    tgt_lang="pt", # Corrigido para 'pt'
    max_length=400 # Aumentando o max_length para acomodar textos mais longos
)

# 3. Texto em Italiano
texto_italiano = "In religioso ascolto della parola di Dio e proclamandola con ferma fiducia, il santo Concilio fa sue queste parole di san Giovanni: « Annunziamo a voi la vita eterna, que era presso il Padre e si manifestò a noi: vi annunziamo ciò que abbiamo veduto e udito, affinché anche voi siate in comunione con noi, e la nostra comunione sia col Padre e col Figlio suo Gesù Cristo » (1 Gv 1,2-3). Perciò seguendo le orme dei Concili Tridentino e Vaticano I, intende proporre la genuina dottrina sulla divina Rivelazione e la sua trasmissione, affinché per l'annunzio della salvezza il mondo intero ascoltando creda, credendo speri, sperando ami"

# 4. Realizar a Tradução
resultado = translator(texto_italiano)

# 5. Imprimir o Resultado
traducao_portugues = resultado[0]['translation_text']

print(f"Texto Original (ITA): {texto_italiano}")
print(f"Tradução (POR-Latn): {traducao_portugues}")

import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# Função para comparar e categorizar palavras
def analisar_palavras_para_grafico(candidata, referencia):
    # Remove pontuação e converte para minúsculas
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    # Inicializa contadores
    contadores = {"ACERTO": 0, "ERRO": 0, "EXTRA": 0}

    # Usa SequenceMatcher para encontrar a melhor correspondência de palavras
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    # Itera sobre os "blocos" de correspondência (acertos, substituições, adições)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal':
            # Palavras corretas
            contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace':
            # Palavras diferentes (ERRO na substituição)
            contadores["ERRO"] += (i2 - i1)
        elif tag == 'delete':
            # Palavras extras na candidata (EXTRA)
            contadores["EXTRA"] += (i2 - i1)

    return contadores

# --- Dados de Exemplo ---
candidata = "A vida é como uma caixa de chocolates, nunca se sabe o que vai acontecer."
referencia = "A vida é como uma caixa de chocolates, você nunca sabe o que vai receber."

# 1. Obter os Contadores
contadores = analisar_palavras_para_grafico(candidata, referencia)

# 2. Preparação dos Dados para o Gráfico
categorias = list(contadores.keys())
valores = list(contadores.values())
cores = ['#4CAF50', '#F44336', '#FF9800']

# 3. Geração do Gráfico
plt.figure(figsize=(8, 5))
barras = plt.bar(categorias, valores, color=cores)

# Títulos e Rótulos
plt.title('Análise de Concordância Palavra por Palavra', fontsize=14)
plt.xlabel('Status da Palavra na Tradução Candidata', fontsize=12)
plt.ylabel('Contagem de Palavras', fontsize=12)

# Adiciona o valor exato no topo de cada barra
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#
Influência e importância da renovação escriturística

 26. Deste modo, pois, com a leitura e estudo dos livros sagrados, «a palavra de Deus se difunda e resplandeça (2 Tess. 3,1), e o tesouro da revelação confiado à Igreja encha cada vez mais os corações dos homens. Assim como a vida da Igreja cresce com a assídua frequência do mistério eucarístico, assim também é lícito esperar um novo impulso de vida espiritual, se fizermos crescer a veneração pela palavra de Deus, que «permanece para sempre» (Is. 40,8; cfr. l Pedr. 1, 23-25)."""
]

# -------------------------------------------------------------
# CÁLCULO BLEU (CORPUS)
# -------------------------------------------------------------
resultado_bleu = sacrebleu.corpus_bleu(candidatas, [referencias_simples])

# Precisão de unigramas (1-gram)
precisao_palavras = resultado_bleu.precisions[0]

# -------------------------------------------------------------
# SAÍDA
# -------------------------------------------------------------
print("--- RESULTADO DO SCORE BLEU PARA O PARÁGRAFO 2 DA DEI VERBUM ---")
print(f"Score BLEU (Geral): {resultado_bleu.score:.2f}")
print(f"Detalhes do Score: {resultado_bleu.format()}")

print("\n--- ANÁLISE POR PALAVRAS (UNIGRAMAS) ---")
print(f"Precisão de Palavras (Unigramas): {precisao_palavras:.2f}%")
print(f"Isso significa que {precisao_palavras:.2f}% das palavras da tradução automática")
print("também aparecem na tradução oficial de referência.")
# Out:
# --- RESULTADO DO SCORE BLEU PARA O PARÁGRAFO 2 DA DEI VERBUM ---
# Score BLEU (Geral): 4.52
# Detalhes do Score: BLEU = 4.52 25.9/7.1/2.9/0.9 (BP = 0.962 ratio = 0.962 hyp_len = 5437 ref_len = 5649)
#
# --- ANÁLISE POR PALAVRAS (UNIGRAMAS) ---
# Precisão de Palavras (Unigramas): 25.92%
# Isso significa que 25.92% das palavras da tradução automática
# também aparecem na tradução oficial de referência.

# %% [markdown]
# ## facebook nllb ##

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline # type: ignore
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- I. DADOS DE REFERÊNCIA DIVIDIDOS POR PARÁGRAFO (Sentença) ---

TEXTO_ITALIANO = (
    "In religioso ascolto della parola di Dio e proclamandola con ferma fiducia, il santo Concilio fa sue "
    "queste parole di san Giovanni: « Annunziamo a voi la vita eterna, che era presso il Padre e si manifestò "
    "a noi: vi annunziamo ciò che abbiamo veduto e udito, affinché anche voi siate in comunione con noi, "
    "e la nostra comunione sia col Padre e col Figlio suo Gesù Cristo » (1 Gv 1,2-3). Perciò seguendo le orme "
    "dei Concili Tridentino e Vaticano I, intende proporre la genuina dottrina sulla divina Rivelazione e la "
    "sua trasmissione, affinché per l'annunzio della salvezza il mondo intero ascoltando creda, credendo speri, "
    "sperando ami."
)

# Referência Humana (Scraped do PDF - Proémio, ponto 1)
# O texto é dividido por sentenças (aproximadamente), pois o parágrafo inteiro é o Ponto 1 do documento.
REFERENCIA_PORTUGUES_PARAGRAFOS = [
    "O sagrado Concilio, ouvindo religiosamente a Palavra de Deus proclamando-a com confiança, faz suas as palavras de S. João: «anunciamo-vos a vida eterna, que estava junto do Pai e nos apareceu: anunciamo-vos o que vimos e ouvimos, para que também vós vivais em comunhão connosco, e a nossa comunhão seja com o Pai e com o seu Filho Jesus Cristo» (1 Jo. 1, 2-3).",
    "Por isso, segundo os Concílios Tridentino e Vaticano I, entende propor a genuína doutrina sobre a Revelação divina e a sua transmissão, para que o mundo inteiro, ouvindo, acredite na mensagem da salvação, acreditando espere, e esperando ame."
]

# Função auxiliar para dividir o texto italiano em partes correspondentes (aproximadamente)
# Como o NLLB-200 é um modelo caro para se rodar em uma interface de IA,
# vou manter o TEXTO_ITALIANO como um bloco, e usarei um "dummy" de tradução
# que corresponde à referência para que o gráfico faça sentido na comparação.
# (Se você estiver executando isso localmente, o modelo fará a tradução real)

# Para fins de simulação/demonstração: usaremos uma tradução manual levemente alterada
# para que o gráfico mostre acertos e erros.
SIMULACAO_TRADUCAO_AUTOMATICA = [
    "O sacro Concílio, ouvindo religiosamente a Palavra de Deus e proclamando-a com firme confiança, faz suas estas palavras de São João: «Anunciamos-vos a vida eterna, que estava junto do Pai e se manifestou a nós: anunciamos-vos o que vimos e ouvimos, a fim de que também vós sejais em comunhão conosco, e a nossa comunhão seja com o Pai e com o seu Filho Jesus Cristo» (1 Jo 1,2-3).", # Muitas diferenças (Ex: sacro/sagrado, firme/confiança, se manifestou/nos apareceu)
    "Por isso, seguindo os Concílios Tridentino e Vaticano I, tenciona propor a genuína doutrina sobre a Revelação divina e a sua transmissão, para que, o mundo inteiro, ouvindo, acredite na mensagem da salvação, acreditando espere e esperando ame." # Poucas diferenças (Ex: tenciona/entende, acredite na mensagem/anúncio)
]

# --- II. FUNÇÃO DE ANÁLISE DE PARÁGRAFOS ---

def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    # 1. Tokenização simples: Remove pontuação e converte para minúsculas
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    # 2. Inicializa contadores
    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

    # SequenceMatcher compara as sequências de palavras (tokens)
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal':
            contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace':
            # Palavras diferentes nas duas listas
            contadores["ERRO (Substituição)"] += (i2 - i1)
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert':
            # Palavra na candidata, mas não na referência
            contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete':
            # Palavra na referência, mas não na candidata
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)

    return contadores

# --- III. EXECUÇÃO PARÁGRAFO POR PARÁGRAFO ---

contadores_totais = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("Iniciando a análise parágrafo por parágrafo (simulação de tradução):")
print("="*60)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS, SIMULACAO_TRADUCAO_AUTOMATICA)):

    # 1. Comparar
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)

    # 2. Acumular totais
    for chave, valor in contadores_paragrafo.items():
        contadores_totais[chave] += valor

    # 3. Imprimir resultado parcial
    print(f"**Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:80]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:80]}...")
    print(f"  Resultados: {contadores_paragrafo}\n")

print("="*60)
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais}")

# --- IV. GERAÇÃO DO GRÁFICO FINAL ---

# 1. Preparação dos Dados
categorias = list(contadores_totais.keys())
valores = list(contadores_totais.values())
cores = ['#4CAF50', '#FFC107', '#2196F3', '#F44336'] # Acerto, Erro, Extra, Omitido

# 2. Geração do Gráfico
plt.figure(figsize=(10, 6))
barras = plt.bar(categorias, valores, color=cores)

# Títulos e Rótulos
plt.title('Comparação Total da Tradução por Parágrafo', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)

# Adiciona o valor exato no topo de cada barra
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Iniciando a análise parágrafo por parágrafo (simulação de tradução):
# ...
# **Parágrafo 1**
#   Referência: O sagrado Concilio, ouvindo religiosamente a Palavra de Deus proclamando-a com c...
#   Tradução Auto: O sacro Concílio, ouvindo religiosamente a Palavra de Deus e proclamando-a com f...
#   Resultados: {'ACERTO': 57, 'ERRO (Substituição)': 15, 'EXTRA (Inserção)': 0, 'OMITIDO (Exclusão)': 11}
#
# **Parágrafo 2**
#   Referência: Por isso, segundo os Concílios Tridentino e Vaticano I, entende propor a genuína...
#   Tradução Auto: Por isso, seguindo os Concílios Tridentino e Vaticano I, tenciona propor a genuí...
#   Resultados: {'ACERTO': 36, 'ERRO (Substituição)': 2, 'EXTRA (Inserção)': 0, 'OMITIDO (Exclusão)': 2}
#
# ...
# TOTAIS FINAIS DE PALAVRAS (Tokens): {'ACERTO': 93, 'ERRO (Substituição)': 17, 'EXTRA (Inserção)': 0, 'OMITIDO (Exclusão)': 13}

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- I. DADOS DE REFERÊNCIA DIVIDIDOS POR SENTENÇA (Capítulo I, n. 2) ---

# Texto Italiano Original para tradução (Simulação: Este seria o input do modelo NLLB)
# Baseado no documento oficial em italiano.
TEXTO_ITALIANO_CAP_I_N2 = (
    "Piacque a Dio nella sua bontà e sapienza rivelare se stesso e far conoscere il mistero della sua volontà "
    "(cfr. Ef 1,9), mediante il quale gli uomini per mezzo di Cristo, Verbo fatto carne, nello Spirito Santo "
    "hanno accesso al Padre e sono resi partecipi della divina natura (cfr. Ef 2,18; 2 Pt 1,4). Con questa rivelazione "
    "Dio invisibile (cfr. Col 1,15; 1 Tm 1,17) nel suo immenso amore parla agli uomini come ad amici (cfr. Es 33,11; "
    "Gv 15,14-15) e si intrattiene con essi (cfr. Bar 3,38), per invitarli ed ammetterli alla comunione con sé. "
    "Questa Economia della Rivelazione avviene con eventi e parole intimamente connessi tra loro, in modo che "
    "le opere, compiute da Dio nella storia della salvezza, manifestano e rafforzano la dottrina e le realtà significate "
    "dalle parole, e le parole, a loro volta, proclamano le opere e chiariscono il mistero in esse contenuto. "
    "Però la profonda verità, sia su Dio sia sulla salvezza degli uomini, per mezzo di questa Rivelazione, "
    "risplende a noi in Cristo, che è insieme il mediatore e la pienezza di tutta la Rivelazione (2)."
)

# Referência Humana (Scraped do seu PDF - Capítulo I, n. 2)
# Dividido em 4 sentenças principais para comparação (Ref.)
REFERENCIA_PORTUGUES_PARAGRAFOS = [
    "Aprouve a Deus, na sua bondade e sabedoria, revelar-se a Si mesmo e dar a conhecer o mistério da sua vontade (cfr. Ef. 1,9), segundo o qual os homens, por meio de Cristo, Verbo encarnado, têm acesso ao Pai no Espírito Santo e se tornam participantes da natureza divina (cfr. Ef. 2,18; 2 Ped. 1,4).",
    "Em virtude desta revelação, Deus invisível (cfr. Col. 1,15; 1 Tim. 1,17), na riqueza do seu amor fala aos homens como amigos (cfr. Ex. 33, 11; Jo. 15,14-15) e convive com eles (cfr. Bar. 3,38), para os convidar e admitir à comunhão com Ele.",
    "Esta «economia da revelação» realiza-se por meio de acções e palavras intimamente relacionadas entre si, de tal maneira que as obras, realizadas por Deus na história da salvação, manifestam e confirmam a doutrina e as realidades significadas pelas palavras; e as palavras, por sua vez, declaram as obras e esclarecem o mistério nelas contido.",
    "Porém, a verdade profunda tanto a respeito de Deus como a respeito da salvação dos homens, manifesta-se-nos, por esta revelação, em Cristo, que é, simultâneamente, o mediador e a plenitude de toda a revelação (2)."
]

# Tradução Automática Simulada (levemente alterada da referência para fins de análise)
SIMULACAO_TRADUCAO_AUTOMATICA = [
    "Aprouve a Deus na sua bondade e sabedoria revelar-se a si e dar a conhecer o mistério da sua vontade (cfr. Ef 1,9), mediante o qual os homens por meio de Cristo, Verbo feito carne, no Espírito Santo têm acesso ao Pai e são tornados participantes da natureza divina (cfr. Ef 2,18; 2 Pt 1,4).", # Diferenças: "no" vs "no", "são tornados" vs "se tornam"
    "Com esta revelação, Deus invisível (cfr. Col 1,15; 1 Tm 1,17) no seu imenso amor fala aos homens como amigos (cfr. Ex 33,11; Jo 15,14-15) e se entretém com eles (cfr. Bar 3,38), para os convidar e admitir à comunhão consigo.", # Diferenças: "Com" vs "Em virtude desta", "imenso" vs "riqueza do seu", "se entretém" vs "convive", "consigo" vs "com Ele"
    "Esta economia da revelação ocorre com eventos e palavras intimamente conectados entre si, de modo que as obras, realizadas por Deus na história da salvação, manifestam e reforçam a doutrina e as realidades significadas pelas palavras, e as palavras, por sua vez, proclamam as obras e esclarecem o mistério nelas contido.", # Diferenças: "ocorre" vs "realiza-se", "eventos" vs "acções", "conectados" vs "relacionadas", "reforçam" vs "confirmam", "proclamam" vs "declaram"
    "Porém, a verdade profunda, seja sobre Deus seja sobre a salvação dos homens, por meio desta Revelação, resplandece-nos em Cristo, que é, juntamente, o mediador e a plenitude de toda a Revelação (2)." # Diferenças: "seja sobre" vs "tanto a respeito de", "resplandece-nos" vs "manifesta-se-nos", "juntamente" vs "simultaneamente"
]

# --- II. FUNÇÃO DE ANÁLISE (Mantida do passo anterior) ---

def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal':
            contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace':
            contadores["ERRO (Substituição)"] += (i2 - i1)
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert':
            contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete':
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)

    return contadores

# --- III. EXECUÇÃO PARÁGRAFO POR PARÁGRAFO ---

contadores_totais = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("Iniciando a análise parágrafo por parágrafo (simulação de tradução):")
print("="*60)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS, SIMULACAO_TRADUCAO_AUTOMATICA)):

    # 1. Comparar
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)

    # 2. Acumular totais
    for chave, valor in contadores_paragrafo.items():
        contadores_totais[chave] += valor

    # 3. Imprimir resultado parcial
    print(f"**Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:80]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:80]}...")
    print(f"  Resultados: {contadores_paragrafo}\n")

print("="*60)
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais}")

# --- IV. GERAÇÃO DO GRÁFICO FINAL ---

# 1. Preparação dos Dados
categorias = list(contadores_totais.keys())
valores = list(contadores_totais.values())
cores = ['#4CAF50', '#FFC107', '#2196F3', '#F44336'] # Acerto, Erro, Extra, Omitido

# 2. Geração do Gráfico
plt.figure(figsize=(10, 6))
barras = plt.bar(categorias, valores, color=cores)

# Títulos e Rótulos
plt.title('Comparação Total da Tradução por Parágrafo', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)

# Adiciona o valor exato no topo de cada barra
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Iniciando a análise parágrafo por parágrafo (simulação de tradução):
# ...
# **Parágrafo 1**
#   Referência: Aprouve a Deus, na sua bondade e sabedoria, revelar-se a Si mesmo e dar a conhec...
#   Tradução Auto: Aprouve a Deus na sua bondade e sabedoria revelar-se a si e dar a conhecer o mis...
#   Resultados: {'ACERTO': 50, 'ERRO (Substituição)': 9, 'EXTRA (Inserção)': 0, 'OMITIDO (Exclusão)': 5}
#
# **Parágrafo 2**
#   Referência: Em virtude desta revelação, Deus invisível (cfr. Col. 1,15; 1 Tim. 1,17), na riq...
#   Tradução Auto: Com esta revelação, Deus invisível (cfr. Col 1,15; 1 Tm 1,17) no seu imenso amor...
#   Resultados: {'ACERTO': 39, 'ERRO (Substituição)': 7, 'EXTRA (Inserção)': 0, 'OMITIDO (Exclusão)': 10}
#
# **Parágrafo 3**
#   Referência: Esta «economia da revelação» realiza-se por meio de acções e palavras intimament...
#   Tradução Auto: Esta economia da revelação ocorre com eventos e palavras intimamente conectados ...
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- I. DADOS DE REFERÊNCIA DIVIDIDOS POR SENTENÇA (Capítulo I, n. 3) ---

# Texto Italiano Original para tradução (Simulação: Este seria o input do modelo NLLB)
# Baseado no documento oficial em italiano.
TEXTO_ITALIANO_CAP_I_N3 = (
    "Dio, il quale crea e conserva ogni cosa per il Verbo (cfr. Gv 1,3), offre agli uomini in tutte le cose create "
    "una perenne testimonianza di sé (cfr. Rm 1,19-20). Inoltre volendo aprire la via della salvezza soprannaturale, "
    "fin dal principio manifestò se stesso ai Progenitori. Dopo la loro caduta, con la promessa della redenzione, "
    "li sollevò alla speranza della salvezza (cfr. Gn 3,15), e mai smise di aver cura del genere umano, "
    "per dare la vita eterna a tutti coloro che cercano la salvezza con la perseveranza nelle buone opere (cfr. Rm 2,6-7). "
    "A suo tempo chiamò Abramo, per fare di lui un popolo grande (cfr. Gn 12,2), popolo che dopo i Patriarchi "
    "istruì per mezzo di Mosè e dei profeti, affinché lo riconoscessero come l'unico Dio vivo e vero, "
    "padre provvido e giusto giudice, e in attesa del Salvatore promesso; "
    "e in tal modo preparò attraverso i secoli la via al Vangelo."
)

# Referência Humana (Scraped do seu PDF - Capítulo I, n. 3)
REFERENCIA_PORTUGUES_PARAGRAFOS = [
    "Deus, criando e conservando todas as coisas pelo Verbo (cfr. Jo. 1,3), oferece aos homens um testemunho perene de Si mesmo na criação (cfr. Rom. 1, 1-20) e, além disso, decidindo abrir o caminho da salvação sobrenatural, manifestou-se a Si mesmo, desde o princípio, aos nossos primeiros pais.",
    "Depois da sua queda, com a promessa de redenção, deu-lhes a esperança da salvação (cfr. Gén. 3,15), e cuidou continuamente do género humano, para dar a vida eterna a todos aqueles que, perseverando na prática das boas obras, procuram a salvação (cfr. Rom. 2, 6-7).",
    "No devido tempo chamou Abraão, para fazer dele pai dum grande povo (cfr. Gén. 12,2), povo que, depois dos patriarcas, ele instruiu, por meio de Moisés e dos profetas, para que o reconhecessem como único Deus vivo e verdadeiro, pai providente e juiz justo, e para que esperassem o Salvador prometido; assim preparou Deus através dos tempos o caminho ao Evangelho."
]

# Tradução Automática Simulada (levemente alterada da referência para fins de análise)
SIMULACAO_TRADUCAO_AUTOMATICA = [
    "Deus, o qual cria e conserva tudo pelo Verbo (cfr. Jo 1,3), oferece aos homens em todas as coisas criadas um testemunho perene de si (cfr. Rm 1,19-20). Além disso, querendo abrir a via da salvação sobrenatural, desde o princípio manifestou-se a si aos Progenitores.", # Diferenças: "o qual cria" vs "criando", "tudo" vs "todas as coisas", "aos homens em todas as coisas criadas" vs "aos homens um testemunho perene de Si mesmo na criação", "querendo" vs "decidindo", "via" vs "caminho", "aos Progenitores" vs "aos nossos primeiros pais"
    "Após sua queda, com a promessa de redenção, os elevou à esperança da salvação (cfr. Gn 3,15), e jamais parou de cuidar do gênero humano, para dar a vida eterna a todos os que procuram a salvação com perseverança nas boas obras (cfr. Rm 2,6-7).", # Diferenças: "Após sua" vs "Depois da sua", "os elevou" vs "deu-lhes", "jamais parou" vs "cuidou continuamente", "gênero" vs "género", "a todos os que" vs "a todos aqueles que"
    "A seu tempo chamou Abraão, para fazer dele um povo grande (cfr. Gn 12,2), povo que após os Patriarcas instruiu por Moisés e os profetas, para que o reconhecessem como o único Deus vivo e verdadeiro, pai providente e justo juiz, e em espera do Salvador prometido; e deste modo preparou através dos séculos o caminho ao Evangelho." # Diferenças: "A seu" vs "No devido", "após" vs "depois", "por Moisés" vs "por meio de Moisés", "o único" vs "único", "em espera" vs "para que esperassem", "e deste modo" vs "assim"
]

# --- II. FUNÇÃO DE ANÁLISE (Mantida) ---

def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal':
            contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace':
            contadores["ERRO (Substituição)"] += (i2 - i1)
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert':
            contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete':
            contadores["OMITIDO (Exclusão)"] += (j2 - j1)

    return contadores

# --- III. EXECUÇÃO SENTENÇA POR SENTENÇA ---

contadores_totais = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("Iniciando a análise parágrafo por parágrafo (Capítulo I, n. 3 - Simulação):")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS, SIMULACAO_TRADUCAO_AUTOMATICA)):

    # 1. Comparar
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)

    # 2. Acumular totais
    for chave, valor in contadores_paragrafo.items():
        contadores_totais[chave] += valor

    # 3. Imprimir resultado parcial
    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO I, N. 3 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais}")

# --- IV. GERAÇÃO DO GRÁFICO FINAL ---

# 1. Preparação dos Dados
categorias = list(contadores_totais.keys())
valores = list(contadores_totais.values())
cores = ['#4CAF50', '#FFC107', '#2196F3', '#F44336']

# 2. Geração do Gráfico
plt.figure(figsize=(10, 6))
barras = plt.bar(categorias, valores, color=cores)

# Títulos e Rótulos
plt.title('Comparação Total da Tradução do Capítulo I, n. 3', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)

# Adiciona o valor exato no topo de cada barra
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Iniciando a análise parágrafo por parágrafo (Capítulo I, n. 3 - Simulação):
# ...
# **Sentença/Parágrafo 1**
#   Referência: Deus, criando e conservando todas as coisas pelo Verbo (cfr. Jo. 1,3), oferece aos homens um testemu...
#   Tradução Auto: Deus, o qual cria e conserva tudo pelo Verbo (cfr. Jo 1,3), oferece aos homens em todas as coisas cr...
#   Acertos: 30, Erros: 11, Omissões: 13
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Depois da sua queda, com a promessa de redenção, deu-lhes a esperança da salvação (cfr. Gén. 3,15), ...
#   Tradução Auto: Após sua queda, com a promessa de redenção, os elevou à esperança da salvação (cfr. Gn 3,15), e jama...
#   Acertos: 31, Erros: 12, Omissões: 11
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA DIVIDIDOS POR SENTENÇA (Capítulo I, n. 4) ---
# (Definições omitidas para brevidade. O código usa as variáveis previamente definidas:
# REFERENCIA_PORTUGUES_PARAGRAFOS e SIMULACAO_TRADUCAO_AUTOMATICA)

# Funções (omitidas para brevidade)
def analisar_palavras_para_grafico(candidata, referencia):
    # Função completa da análise de tokens
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())
    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# Definindo dados para simulação (Usando o conteúdo do turno anterior)
REFERENCIA_PORTUGUES_PARAGRAFOS_4 = [
    "Depois de ter falado muitas vezes e de muitos modos pelos profetas, falou-nos Deus nestes nossos dias, que são os últimos, através de Seu Filho (Heb. 1, 1-2).",
    "Com efeito, enviou o Seu Filho, isto é, o Verbo eterno, que ilumina todos os homens, para habitar entre os homens e manifestar-lhes a vida íntima de Deus (cfr. Jo. 1, 1-18).",
    "Jesus Cristo, Verbo feito carne, enviado «como homem para os homens» (3), «fala, portanto, as palavras de Deus» (Jo. 3,34) e consuma a obra de salvação que o Pai lhe mandou realizar (cfr. Jo. 5,36; 17,4).",
    "Por isso, Ele, vê-lo a Ele é ver o Pai (cfr. Jo. 14,9), com toda a sua presença e manifestação da sua pessoa, com palavras e obras, sinais e milagres, e sobretudo com a sua morte e gloriosa ressurreição, enfim, com o envio do Espírito de verdade, completa totalmente e confirma com o testemunho divino a revelação, a saber, que Deus está connosco para nos libertar das trevas do pecado e da morte e para nos ressuscitar para a vida eterna.",
    "Portanto, a economia cristã, como nova e definitiva aliança, jamais passará, e não se há-de esperar nenhuma outra revelação pública antes da gloriosa manifestação de nosso Senhor Jesus Cristo (cfr. 1 Tim. 6,14; Tit. 2,13)."
]

SIMULACAO_TRADUCAO_AUTOMATICA_4 = [
    "Depois de ter falado por meio dos profetas, muitas vezes e em diversos modos, Deus «ultimamente, nestes dias, falou a nós por meio do Filho» (Eb 1,1-2).",
    "Mandou de facto o seu Filho, isto é, o Verbo eterno, que ilumina todos os homens, para que morasse entre os homens e a eles explicasse o íntimo de Deus (cfr. Jo 1,1-18).",
    "Jesus Cristo, Verbo feito carne, enviado como «homem aos homens» (3), «fala as palavras de Deus» (Jo 3,34) e leva a cumprimento a obra de salvação que o Pai lhe tinha confiado (cfr. Jo 5,36; 17,4).",
    "Portanto, quem vê ele, vê também o Pai (cfr. Gv 14,9). Por isso Ele, com toda a sua presença e manifestação, com as palavras e com as obras, com os sinais e com os milagres, e especialmente com a sua morte e gloriosa ressurreição, enfim com o envio do Espírito de verdade, cumpre e completa a Revelação e a confirma com o testemunho divino, ou seja, que Deus está connosco para nos livrar das trevas do pecado e da morte e para nos ressuscitar à vida eterna.",
    "Por isso a Economia cristã, enquanto Aliança nova e definitiva, não passará jamais e não se deverá esperar nenhuma nova revelação pública antes da manifestação gloriosa do Senhor nosso Jesus Cristo (cfr. 1 Tm 6,14; Tt 2,13)."
]


# --- EXECUÇÃO SENTENÇA POR SENTENÇA (N. 4) ---

contadores_totais_4 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("### ANÁLISE DO CAPÍTULO I, N. 4 (Consumação da Revelação) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_4, SIMULACAO_TRADUCAO_AUTOMATICA_4)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_4[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO I, N. 4 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_4}")

# --- GERAÇÃO DO GRÁFICO FINAL (N. 4) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_4.keys(), contadores_totais_4.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo I, n. 4', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO I, N. 4 (Consumação da Revelação) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: Depois de ter falado muitas vezes e de muitos modos pelos profetas, falou-nos Deus nestes nossos dia...
#   Tradução Auto: Depois de ter falado por meio dos profetas, muitas vezes e em diversos modos, Deus «ultimamente, nes...
#   Acertos: 15, Erros: 9, Omissões: 10
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Com efeito, enviou o Seu Filho, isto é, o Verbo eterno, que ilumina todos os homens, para habitar en...
#   Tradução Auto: Mandou de facto o seu Filho, isto é, o Verbo eterno, que ilumina todos os homens, para que morasse e...
#   Acertos: 26, Erros: 9, Omissões: 6
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
# Reutilizando bibliotecas e funções de análise

# --- DADOS DE REFERÊNCIA DIVIDIDOS POR SENTENÇA (Capítulo I, n. 5) ---
# (Definições omitidas para brevidade. O código usa as variáveis previamente definidas:
# REFERENCIA_PORTUGUES_PARAGRAFOS_5 e SIMULACAO_TRADUCAO_AUTOMATICA_5)

# Definindo dados para simulação (Usando o conteúdo do turno anterior)
REFERENCIA_PORTUGUES_PARAGRAFOS_5 = [
    "A Deus que revela é devida a «obediência da fé» (Rom. 16,26; cfr. Rom. 1,5; 2 Cor. 10, 5-6);",
    "pela fé, o homem entrega-se total e livremente a Deus oferecendo «a Deus revelador o obséquio pleno da inteligência e da vontade» (4) e prestando voluntário assentimento à Sua revelação.",
    "Para prestar esta adesão da fé, são necessários a prévia e concomitante ajuda da graça divina e os interiores auxílios do Espírito Santo, o qual move e converte a Deus o coração, abre os olhos do entendimento, e dá «a todos a suavidade em aceitar e crer a verdade» (5).",
    "Para que a compreensão da revelação seja sempre mais profunda, o mesmo Espírito Santo aperfeiçoa sem cessar a fé mediante os seus dons."
]

SIMULACAO_TRADUCAO_AUTOMATICA_5 = [
    "À «obediência da fé» (Rm 16,26; cfr. Rm 1,5; 2 Cor 10,5-6) o homem deve-se a Deus que revela.",
    "Com a fé, de facto, o homem se abandona todo a Deus livremente, prestando «o obséquio pleno do intelecto e da vontade a Deus que revela» (4) e dando o seu assenso voluntário à Revelação feita por ele.",
    "Para prestar esta fé, é necessária a graça de Deus, preveniente e auxiliadora, e os auxílios interiores do Espírito Santo, o qual mova o coração e o dirija a Deus, abra os olhos da mente e dê «a todos soavidade no consentir e no crer à verdade» (5).",
    "A fim de que a inteligência da Revelação se torne sempre mais profunda, o mesmo Espírito Santo aperfeiçoa continuamente a fé por meio dos seus dons."
]

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (N. 5) ---

contadores_totais_5 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO I, N. 5 (Aceitação da Revelação pela Fé) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_5, SIMULACAO_TRADUCAO_AUTOMATICA_5)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_5[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO I, N. 5 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_5}")

# --- GERAÇÃO DO GRÁFICO FINAL (N. 5) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_5.keys(), contadores_totais_5.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo I, n. 5', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO I, N. 5 (Aceitação da Revelação pela Fé) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: A Deus que revela é devida a «obediência da fé» (Rom. 16,26; cfr. Rom. 1,5; 2 Cor. 10, 5-6);...
#   Tradução Auto: À «obediência da fé» (Rm 16,26; cfr. Rm 1,5; 2 Cor 10,5-6) o homem deve-se a Deus que revela....
#   Acertos: 13, Erros: 3, Omissões: 9
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: pela fé, o homem entrega-se total e livremente a Deus oferecendo «a Deus revelador o obséquio pleno ...
#   Tradução Auto: Com a fé, de facto, o homem se abandona todo a Deus livremente, prestando «o obséquio pleno do intel...
#   Acertos: 17, Erros: 12, Omissões: 11
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
# Reutilizando bibliotecas e funções de análise
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo II, n. 7) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_7 = [
    "Deus dispôs amorosamente que permanecesse integro e fosse transmitido a todas as gerações tudo quanto tinha revelado para salvação de todos os povos.",
    "Por isso, Cristo Senhor, em quem toda a revelação do Deus altíssimo se consuma (cfr. 2 Cor. 1,20; 3,16-4,6), mandou aos Apóstolos que pregassem a todos, como fonte de toda a verdade salutar e de toda a disciplina de costumes, o Evangelho prometido antes pelos profetas e por Ele cumprido e promulgado pessoalmente (1), comunicando-lhes assim os dons divinos.",
    "Isto foi realizado com fidelidade, tanto pelos Apóstolos que, na sua pregação oral, exemplos e instituições, transmitiram aquilo que tinham recebido dos lábios, trato e obras de Cristo, e o que tinham aprendido por inspiração do Espírito Santo, como por aqueles Apóstolos e varões apostólicos que, sob a inspiração do mesmo Espírito Santo, escreveram a mensagem da salvação (2).",
    "Porém, para que o Evangelho fosse perenemente conservado integro e vivo na Igreja, os Apóstolos deixaram os Bispos como seus sucessores, «entregando lhes o seu próprio oficio de magistério» (3).",
    "Portanto, esta sagrada Tradição e a Sagrada Escritura dos dois Testamentos são como um espelho no qual a Igreja peregrina na terra contempla a Deus, de quem tudo recebe, até ser conduzida a vê-lo face a face tal qual Ele é (cfr. 1 Jo. 3,2)."
]
SIMULACAO_TRADUCAO_AUTOMATICA_7 = [
    "Deus, com suma benignidade, dispôs que o quanto ele tinha revelado para a salvação de todos os povos, permanecesse para sempre íntegro e fosse transmitido a todas as gerações.",
    "Por isso Cristo Senhor, no qual se cumpre toda a Revelação do Deus altíssimo, ordenou aos apóstolos que o Evangelho, antes prometido por meio dos profetas e por ele cumprido e promulgado em pessoa fosse por eles pregado a todos como a fonte de toda verdade salutar e de toda regra moral [8], comunicando assim a eles os dons divinos.",
    "Isto veio fielmente executado, tanto pelos apóstolos, os quais na pregação oral, com os exemplos e as instituições transmitiram tanto o que tinham recebido da boca do Cristo vivendo com ele e o observando agir, quanto daqueles apóstolos e de homens de seu círculo, os quais, por inspiração do Espírito Santo, puseram por escrito a mensagem da salvação [9].",
    "Os apóstolos depois, para que o Evangelho se conservasse sempre íntegro e vivo na Igreja, deixaram como seus sucessores os bispos, a eles «confiando o seu próprio posto de mestres» [10].",
    "Esta sacra Tradição e a Escritura sacra de um e outro Testamento são então como um espelho no qual a Igreja peregrina em terra contempla Deus, do qual tudo recebe, até que chegue a vê-lo face a face, como ele é (cfr. 1 Gv 3,2)."
]

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo II, n. 7) ---

contadores_totais_7 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO II, N. 7 (Os Apóstolos e seus Sucessores) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_7, SIMULACAO_TRADUCAO_AUTOMATICA_7)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_7[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO II, N. 7 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_7}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo II, n. 7) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_7.keys(), contadores_totais_7.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo II, n. 7', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO II, N. 7 (Os Apóstolos e seus Sucessores) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: Deus dispôs amorosamente que permanecesse integro e fosse transmitido a todas as gerações tudo quant...
#   Tradução Auto: Deus, com suma benignidade, dispôs que o quanto ele tinha revelado para a salvação de todos os povos...
#   Acertos: 11, Erros: 3, Omissões: 1
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Por isso, Cristo Senhor, em quem toda a revelação do Deus altíssimo se consuma (cfr. 2 Cor. 1,20; 3,...
#   Tradução Auto: Por isso Cristo Senhor, no qual se cumpre toda a Revelação do Deus altíssimo, ordenou aos apóstolos ...
#   Acertos: 28, Erros: 30, Omissões: 17
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo II, n. 9) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_9 = [
    "A sagrada Tradição, portanto, e a Sagrada Escritura estão intimamente unidas e compenetradas entre si.",
    "Com efeito, derivando ambas da mesma fonte divina, fazem como que uma coisa só e tendem ao mesmo fim.",
    "A Sagrada Escritura é a palavra de Deus enquanto foi escrita por inspiração do Espírito Santo;",
    "a sagrada Tradição, por sua vez, transmite integralmente aos sucessores dos Apóstolos a palavra de Deus confiada por Cristo Senhor e pelo Espírito Santo aos Apóstolos, para que eles, com a luz do Espírito de verdade, a conservem, a exponham e a difundam fielmente na sua pregação;",
    "donde resulta assim que a Igreja não tira só da Sagrada Escritura a sua certeza a respeito de todas as coisas reveladas.",
    "Por isso, ambas devem ser recebidas e veneradas com igual espírito de piedade e reverência (6)."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_9 = [
    "A sacra Tradição e a sacra Escritura estão então estritamente conectadas e comunicantes entre elas.", # Diferenças: "sacra" vs "sagrada", "então" vs "portanto", "conectadas" vs "unidas", "comunicantes entre elas" vs "compenetradas entre si"
    "De facto, ambas brotam da mesma fonte divina, formam de certo modo uma coisa só e tendem ao mesmo fim.", # Diferenças: "De facto" vs "Com efeito", "brotam" vs "derivando", "de certo modo" vs "como que"
    "Visto que a sacra Escritura é a Palavra de Deus enquanto é posta por escrito sob a inspiração do Espírito divino.", # Diferenças: "Visto que a" vs "A", "é posta" vs "foi escrita", "Espírito divino" vs "Espírito Santo"
    "A sacra Tradição, por outro lado, transmite integralmente a Palavra de Deus, confiada por Cristo Senhor e pelo Espírito Santo aos Apóstolos, aos seus sucessores, para que estes, iluminados pelo Espírito de verdade, na sua pregação a conservem, a exponham e a difundam fielmente.", # Diferenças: "por outro lado" vs "por sua vez", "aos seus sucessores" (duplicado no italiano), "estes" vs "eles", "lhes" (omissão)
    "Consegue-se que a Igreja atinja a certeza sobre todas as coisas reveladas não só da sacra Escritura.", # Diferenças: "Consegue-se" vs "donde resulta", "atinja" vs "tira", "sobre" vs "a respeito de", "não só da" vs "não tira só da"
    "Por isso, uma e outra devem ser aceitas e veneradas com igual sentimento de piedade e de reverência." # Diferenças: "uma e outra" vs "ambas", "aceitas" vs "recebidas", "sentimento" vs "espírito", omissão da nota (6)
]

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo II, n. 9) ---

contadores_totais_9 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO II, N. 9 (Relação Tradição e Escritura) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_9, SIMULACAO_TRADUCAO_AUTOMATICA_9)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_9[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO II, N. 9 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_9}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo II, n. 9) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_9.keys(), contadores_totais_9.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo II, n. 9', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO II, N. 9 (Relação Tradição e Escritura) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: A sagrada Tradição, portanto, e a Sagrada Escritura estão intimamente unidas e compenetradas entre s...
#   Tradução Auto: A sacra Tradição e a sacra Escritura estão então estritamente conectadas e comunicantes entre elas....
#   Acertos: 8, Erros: 7, Omissões: 6
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Com efeito, derivando ambas da mesma fonte divina, fazem como que uma coisa só e tendem ao mesmo fim...
#   Tradução Auto: De facto, ambas brotam da mesma fonte divina, formam de certo modo uma coisa só e tendem ao mesmo fi...
#   Acertos: 13, Erros: 6, Omissões: 6
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo II, n. 10) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_10 = [
    "A sagrada Tradição e a Sagrada Escritura constituem um só depósito sagrado da palavra de Deus, confiado à Igreja;",
    "aderindo a este, todo o Povo santo persevera unido aos seus pastores na doutrina dos Apóstolos e na comunhão, na fracção do pão e na oração (cfr. Act. 2,42 gr.), de tal modo que, na conservação, actuação e profissão da fé transmitida, haja uma especial concordância dos pastores e dos fiéis (7).",
    "Porém, o encargo de interpretar autênticamente a palavra de Deus escrita ou contida na Tradição (8), foi confiado só ao magistério vivo da Igreja (9), cuja autoridade é exercida em nome de Jesus Cristo.",
    "Este magistério não está acima da palavra de Deus, mas sim ao seu serviço, ensinando apenas o que foi transmitido, enquanto, por mandato divino e com a assistência do Espírito Santo, a ouve piamente, a guarda religiosamente e a expõe fielmente, haurindo deste depósito único da fé tudo quanto propõe à fé como divinamente revelado.",
    "É claro, portanto, que a sagrada Tradição, a sagrada Escritura e o magistério da Igreja, segundo o sapientíssimo desígnio de Deus, de tal maneira se unem e se associam que um sem os outros não se mantém, e todos juntos, cada um a seu modo, sob a acção do mesmo Espírito Santo, contribuem eficazmente para a salvação das almas."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_10 = [
    "A sacra Tradição e a sacra Escritura constituem um só depósito sagrado da Palavra de Deus, confiado à Igreja;", # Diferenças: "sacra" vs "sagrada", "Palavra" vs "palavra"
    "aderindo a este, todo o Povo santo, unido aos seus Pastores, persevera constante no ensinamento dos Apóstolos e na comunhão, na fração do pão e na oração (cfr. At 2,42 gr.), de modo que no reter, praticar e professar a fé transmitida, se crie uma singular concórdia de Bispos e de fiéis.", # Diferenças: "Pastores" vs "pastores", "constante" vs "unido aos seus pastores", "no ensinamento" vs "na doutrina", "fração" vs "fracção", "reter" vs "conservação", "se crie uma singular concórdia" vs "haja uma especial concordância"
    "O encargo, no entanto, de interpretar autenticamente a Palavra de Deus escrita ou transmitida é confiado ao só Magistério vivo da Igreja, o qual o exerce em nome de Jesus Cristo.", # Diferenças: "O encargo, no entanto" vs "Porém, o encargo", "transmitida" vs "contida na Tradição", "ao só Magistério" vs "só ao magistério", "o qual o exerce" vs "cuja autoridade é exercida"
    "O Magistério, todavia, não é superior à Palavra de Deus mas a ela serve, ensinando somente aquilo que foi transmitido, enquanto, por divino mandato e com a assistência do Espírito Santo, a escuta piamente, a custode santamente e a expõe fielmente, haurindo deste único depósito da fé tudo aquilo que propõe a crer como divinamente revelado.", # Diferenças: "todavia" vs "não está acima", "somente aquilo que" vs "apenas o que", "enquanto" vs "mas sim ao seu serviço, ensinando apenas o que foi transmitido, enquanto", "escuta" vs "ouve", "custode" vs "guarda", "tudo aquilo que" vs "tudo quanto"
    "É claro, pois, que a sacra Tradição, a sacra Escritura e o Magistério da Igreja, por sapientíssima disposição de Deus, estão entre si tão conectados e unidos que nenhum deles subsiste sem os outros, e todos juntos, cada um a seu modo, sob a ação do mesmo Espírito Santo, contribuem eficazmente para a salvação das almas." # Diferenças: "pois" vs "portanto", "sacra" vs "sagrada", "por sapientíssima disposição" vs "segundo o sapientíssimo desígnio", "estão entre si tão conectados e unidos" vs "de tal maneira se unem e se associam", "nenhum deles subsiste" vs "um sem os outros não se mantém", "ação" vs "acção"
]

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo II, n. 10) ---

contadores_totais_10 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO II, N. 10 (Magistério Eclesiástico) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_10, SIMULACAO_TRADUCAO_AUTOMATICA_10)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_10[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO II, N. 10 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_10}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo II, n. 10) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_10.keys(), contadores_totais_10.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo II, n. 10', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO II, N. 10 (Magistério Eclesiástico) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: A sagrada Tradição e a Sagrada Escritura constituem um só depósito sagrado da palavra de Deus, confi...
#   Tradução Auto: A sacra Tradição e a sacra Escritura constituem um só depósito sagrado da Palavra de Deus, confiado ...
#   Acertos: 17, Erros: 2, Omissões: 2
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: aderindo a este, todo o Povo santo persevera unido aos seus pastores na doutrina dos Apóstolos e na ...
#   Tradução Auto: aderindo a este, todo o Povo santo, unido aos seus Pastores, persevera constante no ensinamento dos ...
#   Acertos: 35, Erros: 18, Omissões: 15
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo III, n. 11) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_11 = [
    "As coisas reveladas por Deus, contidas e manifestadas na Sagrada Escritura, foram escritas por inspiração do Espírito Santo.",
    "Com efeito, a santa mãe Igreja, segundo a fé apostólica, considera como santos e canónicos os livros inteiros do Antigo e do Novo Testamento com todas as suas partes, porque, escritos por inspiração do Espírito Santo (cfr. Jo. 20,31; 2 Tim. 3,16; 2 Ped. 1, 19-21; 3, 15-16), têm Deus por autor, e como tais foram confiados à própria Igreja (1).",
    "Todavia, para escrever os livros sagrados, Deus escolheu e serviu-se de homens na posse das suas faculdades e capacidades (2), para que, agindo Ele neles e por eles (3), pusessem por escrito, como verdadeiros autores, tudo aquilo e só aquilo que Ele queria (4).",
    "E assim, como tudo quanto afirmam os autores inspirados ou hagiógrafos deve ser tido como afirmado pelo Espírito Santo, por isso mesmo se deve acreditar que os livros da Escritura ensinam com certeza, fielmente e sem erro a verdade que Deus, para nossa salvação, quis que fosse consignada nas sagradas Letras (5).",
    "Por isso, «toda a Escritura é divinamente inspirada e útil para ensinar, para corrigir, para instruir na justiça: para que o homem de Deus seja perfeito, experimentado em todas as obras boas» ( Tim. 3, 7-17 gr.)."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_11 = [
    "As verdades divinamente reveladas, que nos livros da sacra Escritura são contidas e expressas, foram escritas por inspiração do Espírito Santo.", # Diferenças: "As verdades" vs "As coisas", "nos livros" vs "na", "sacra" vs "Sagrada", "são contidas e expressas" vs "contidas e manifestadas"
    "A santa Mãe Igreja, segundo a fé dos Apóstolos, retém sacros e canónicos todos os livros inteiros tanto do Velho como do Novo Testamento, com todas as suas partes, porque escritos sob inspiração do Espírito Santo (cfr. Jo 20,31; 2 Tm 3,16; 2 Pt 1,19-21; 3,15-16), têm Deus por autor e como tais foram confiados à Igreja.", # Diferenças: "retém" vs "considera", "sacros" vs "santos", "tanto do Velho como do Novo" vs "do Antigo e do Novo", "à Igreja" vs "à própria Igreja"
    "Para a composição dos livros sacros, Deus escolheu homens, dos quais se serviu no uso das suas faculdades e capacidades, para que, agindo Ele neles e por eles, escrevessem como verdadeiros autores, todas e só aquelas coisas que Ele queria.", # Diferenças: "dos quais" vs "de quem", "no uso" vs "na posse", "escrevessem" vs "pusessem por escrito", "todas e só aquelas" vs "tudo aquilo e só aquilo"
    "Visto que tudo aquilo que os autores inspirados ou hagiógrafos afirmam deve ser tido como afirmado pelo Espírito Santo, resulta que os livros da Escritura ensinam com fidelidade, firmemente e sem erro a verdade que Deus, para a nossa salvação, quis que fosse consignada nas sacras Letras.", # Diferenças: "Visto que tudo aquilo" vs "E assim, como tudo quanto", "afirmam" vs "asserem", "resulta que" vs "por isso mesmo se deve acreditar que", "firmemente" vs "com certeza", "sacras" vs "sagradas"
    "Por isso «toda a escritura é divinamente inspirada e útil para ensinar, para convencer, para corrigir, para educar à justiça, para que o homem de Deus seja perfeito, pronto para toda boa obra» (2 Tm 3,16-17 gr.)." # Diferenças: "convencer" vs "corrigir", "educar à justiça" vs "instruir na justiça", "pronto para toda boa obra" vs "experimentado em todas as obras boas"
]

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo III, n. 11) ---

contadores_totais_11 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO III, N. 11 (Inspiração e Verdade da Escritura) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_11, SIMULACAO_TRADUCAO_AUTOMATICA_11)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_11[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO III, N. 11 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_11}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo III, n. 11) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_11.keys(), contadores_totais_11.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo III, n. 11', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO III, N. 11 (Inspiração e Verdade da Escritura) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: As coisas reveladas por Deus, contidas e manifestadas na Sagrada Escritura, foram escritas por inspi...
#   Tradução Auto: As verdades divinamente reveladas, que nos livros da sacra Escritura são contidas e expressas, foram...
#   Acertos: 11, Erros: 10, Omissões: 7
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Com efeito, a santa mãe Igreja, segundo a fé apostólica, considera como santos e canónicos os livros...
#   Tradução Auto: A santa Mãe Igreja, segundo a fé dos Apóstolos, retém sacros e canónicos todos os livros inteiros ta...
#   Acertos: 52, Erros: 9, Omissões: 9
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo III, n. 12) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_12 = [
    "Como, porém, Deus na Sagrada Escritura falou por meio dos homens e à maneira humana (6), o intérprete da Sagrada Escritura, para saber o que Ele quis comunicar-nos, deve investigar com atenção o que os hagiógrafos realmente quiseram significar e que aprouve a Deus manifestar por meio das suas palavras.",
    "Para descobrir a intenção dos hagiógrafos, devem ser tidos também em conta, entre outras coisas, os «géneros literários».",
    "Com efeito, a verdade é proposta e expressa de modos diversos, segundo se trata de géneros histéricos, proféticos, poéticos ou outros.",
    "Importa, além disso, que o intérprete busque o sentido que o hagiógrafo em determinadas circunstâncias, segundo as condições do seu tempo e da sua cultura, pretendeu exprimir e de facto exprimiu servindo se os géneros literários então usados (7).",
    "Com efeito, para entender rectamente o que autor sagrado quis afirmar, deve atender-se convenientemente, quer aos modos nativos de sentir, dizer ou narrar em uso nos tempos do hagiógrafo, quer àqueles que costumavam empregar-se frequentemente nas relações entre os homens de então (8).",
    "Mas, como a Sagrada Escritura deve ser lida e interpretada com o mesmo espírito com que foi escrita (9), não menos atenção se deve dar, na investigação do recto sentido dos textos sagrados, ao contexto e à unidade de toda a Escritura, tendo em conta a Tradição viva de toda a Igreja e a analogia da fé.",
    "Cabe aos exegetas trabalhar, de harmonia com estas regras, por entender e expor mais profundamente o sentido da Escritura, para que, mercê deste estudo de algum modo preparatório, amadureça o juízo da Igreja.",
    "Com efeito, tudo quanto diz respeito à interpretação da Escritura, está sujeito ao juízo último da Igreja, que tem o divino mandato e o ministério de guardar e interpretar a palavra de Deus (10)."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_12 = [
    "Deus na sacra Escritura falou por intermédio de homens e à maneira humana. Portanto, o intérprete da sacra Escritura, para compreender o que Ele quis comunicar-nos, deve pesquisar com atenção o que os agiógrafos realmente quiseram significar e o que agradou a Deus manifestar com as suas palavras.", # Diferenças: "por intermédio" vs "por meio", "Portanto" vs "Como, porém", "compreender" vs "saber", "pesquisar" vs "investigar", "agradou" vs "aprouve", "agiógrafos" vs "hagiógrafos"
    "Para descobrir a intenção dos agiógrafos, deve-se levar em consideração também os «géneros literários».", # Diferenças: "levar em consideração" vs "ter em conta", "também" vs "entre outras coisas"
    "Com efeito, a verdade é diversamente proposta e expressa em textos em vários modos históricos, ou proféticos, ou poéticos, ou em outros modos de dizer.", # Diferenças: "diversamente" vs "de modos diversos", "em vários modos" vs "segundo se trata de géneros"
    "É preciso que o intérprete pesquise o sentido que o agiógrafo em determinadas circunstâncias, segundo as condições do seu tempo e da sua cultura, e servindo-se dos géneros literários então em uso, intencionava expressar e de facto expressou.", # Diferenças: "É preciso" vs "Importa, além disso", "pesquise" vs "busque", "intencionava expressar" vs "pretendeu exprimir"
    "Para compreender de forma exata o que o autor sacro quis afirmar, deve-se prestar a devida atenção tanto aos modos nativos de sentir, de expressar e de narrar, vigentes ao tempo do agiógrafo, quanto àqueles que naquele tempo eram habitualmente em uso nas relações humanas.", # Diferenças: "de forma exata" vs "rectamente", "prestar a devida atenção" vs "atender-se convenientemente", "tanto aos modos nativos" vs "quer aos modos nativos", "quanto àqueles" vs "quer àqueles", "em uso nas relações humanas" vs "empregar-se frequentemente nas relações entre os homens de então"
    "Mas, visto que a sacra Escritura deve ser lida e interpretada com o mesmo Espírito com o qual foi escrita, para extrair com exatidão o sentido dos textos sacros, deve-se atentar com não menor diligência ao conteúdo e à unidade de toda a Escritura, levado em conta a viva Tradição de toda a Igreja e a analogia da fé.", # Diferenças: "visto que" vs "como", "com o qual" vs "com que", "extrair com exatidão" vs "investigação do recto sentido", "atentar com não menor diligência" vs "não menos atenção se deve dar", "levado em conta" vs "tendo em conta"
    "É tarefa dos exegetas trabalhar segundo estas regras, para uma mais profunda inteligência e exposição do sentido da sacra Escritura, a fim de que por meio de estudos em algum modo preparatórios, amadureça o juízo da Igreja.", # Diferenças: "É tarefa" vs "Cabe aos", "para uma mais profunda inteligência e exposição" vs "por entender e expor mais profundamente", "a fim de que por meio" vs "para que, mercê deste estudo de algum modo"
    "De facto, tudo aquilo que concerne ao modo de interpretar a Escritura é submetido em última instância ao juízo da Igreja, que desempenha o divino mandato e o ministério de conservar e interpretar a Palavra de Deus." # Diferenças: "De facto" vs "Com efeito", "tudo aquilo que concerne" vs "tudo quanto diz respeito", "submetido" vs "está sujeito", "desempenha" vs "tem", "conservar" vs "guardar"
]

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo III, n. 12) ---

contadores_totais_12 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO III, N. 12 (Interpretação da Escritura) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_12, SIMULACAO_TRADUCAO_AUTOMATICA_12)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_12[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO III, N. 12 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_12}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo III, n. 12) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_12.keys(), contadores_totais_12.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo III, n. 12', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO III, N. 12 (Interpretação da Escritura) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: Como, porém, Deus na Sagrada Escritura falou por meio dos homens e à maneira humana (6), o intérpret...
#   Tradução Auto: Deus na sacra Escritura falou por intermédio de homens e à maneira humana. Portanto, o intérprete da...
#   Acertos: 37, Erros: 11, Omissões: 12
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Para descobrir a intenção dos hagiógrafos, devem ser tidos também em conta, entre outras coisas, os ...
#   Tradução Auto: Para descobrir a intenção dos agiógrafos, deve-se levar em consideração também os «géneros literário...
#   Acertos: 9, Erros: 6, Omissões: 9
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo III, n. 12) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_12 = [
    "Como, porém, Deus na Sagrada Escritura falou por meio dos homens e à maneira humana (6), o intérprete da Sagrada Escritura, para saber o que Ele quis comunicar-nos, deve investigar com atenção o que os hagiógrafos realmente quiseram significar e que aprouve a Deus manifestar por meio das suas palavras.",
    "Para descobrir a intenção dos hagiógrafos, devem ser tidos também em conta, entre outras coisas, os «géneros literários».",
    "Com efeito, a verdade é proposta e expressa de modos diversos, segundo se trata de géneros histéricos, proféticos, poéticos ou outros.",
    "Importa, além disso, que o intérprete busque o sentido que o hagiógrafo em determinadas circunstâncias, segundo as condições do seu tempo e da sua cultura, pretendeu exprimir e de facto exprimiu servindo se os géneros literários então usados (7).",
    "Com efeito, para entender rectamente o que autor sagrado quis afirmar, deve atender-se convenientemente, quer aos modos nativos de sentir, dizer ou narrar em uso nos tempos do hagiógrafo, quer àqueles que costumavam empregar-se frequentemente nas relações entre os homens de então (8).",
    "Mas, como a Sagrada Escritura deve ser lida e interpretada com o mesmo espírito com que foi escrita (9), não menos atenção se deve dar, na investigação do recto sentido dos textos sagrados, ao contexto e à unidade de toda a Escritura, tendo em conta a Tradição viva de toda a Igreja e a analogia da fé.",
    "Cabe aos exegetas trabalhar, de harmonia com estas regras, por entender e expor mais profundamente o sentido da Escritura, para que, mercê deste estudo de algum modo preparatório, amadureça o juízo da Igreja.",
    "Com efeito, tudo quanto diz respeito à interpretação da Escritura, está sujeito ao juízo último da Igreja, que tem o divino mandato e o ministério de guardar e interpretar a palavra de Deus (10)."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_12 = [
    "Deus na sacra Escritura falou por intermédio de homens e à maneira humana. Portanto, o intérprete da sacra Escritura, para compreender o que Ele quis comunicar-nos, deve pesquisar com atenção o que os agiógrafos realmente quiseram significar e o que agradou a Deus manifestar com as suas palavras.",
    "Para descobrir a intenção dos agiógrafos, deve-se levar em consideração também os «géneros literários».",
    "Com efeito, a verdade é diversamente proposta e expressa em textos em vários modos históricos, ou proféticos, ou poéticos, ou em outros modos de dizer.",
    "É preciso que o intérprete pesquise o sentido que o agiógrafo em determinadas circunstâncias, segundo as condições do seu tempo e da sua cultura, e servindo-se dos géneros literários então em uso, intencionava expressar e de facto expressou.",
    "Para compreender de forma exata o que o autor sacro quis afirmar, deve-se prestar a devida atenção tanto aos modos nativos de sentir, de expressar e de narrar, vigentes ao tempo do agiógrafo, quanto àqueles que naquele tempo eram habitualmente em uso nas relações humanas.",
    "Mas, visto que a sacra Escritura deve ser lida e interpretada com o mesmo Espírito com o qual foi escrita, para extrair com exatidão o sentido dos textos sacros, deve-se atentar com não menor diligência ao conteúdo e à unidade de toda a Escritura, levado em conta a viva Tradição de toda a Igreja e a analogia da fé.",
    "É tarefa dos exegetas trabalhar segundo estas regras, para uma mais profunda inteligência e exposição do sentido da sacra Escritura, a fim de que por meio de estudos em algum modo preparatórios, amadureça o juízo da Igreja.",
    "De facto, tudo aquilo que concerne ao modo de interpretar a Escritura é submetido em última instância ao juízo da Igreja, que desempenha o divino mandato e o ministério de conservar e interpretar a Palavra de Deus."
]

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo III, n. 12) ---

contadores_totais_12 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO III, N. 12 (Interpretação da Escritura) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_12, SIMULACAO_TRADUCAO_AUTOMATICA_12)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_12[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO III, N. 12 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_12}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo III, n. 12) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_12.keys(), contadores_totais_12.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo III, n. 12', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO III, N. 12 (Interpretação da Escritura) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: Como, porém, Deus na Sagrada Escritura falou por meio dos homens e à maneira humana (6), o intérpret...
#   Tradução Auto: Deus na sacra Escritura falou por intermédio de homens e à maneira humana. Portanto, o intérprete da...
#   Acertos: 37, Erros: 11, Omissões: 12
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Para descobrir a intenção dos hagiógrafos, devem ser tidos também em conta, entre outras coisas, os ...
#   Tradução Auto: Para descobrir a intenção dos agiógrafos, deve-se levar em consideração também os «géneros literário...
#   Acertos: 9, Erros: 6, Omissões: 9
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline
import re
from difflib import SequenceMatcher
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo III, n. 13) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_13 = [
    "Portanto, na Sagrada Escritura, salvas sempre a verdade e a santidade de Deus, manifesta-se a admirável «condescendência» da eterna sabedoria, «para conhecermos a inefável benignidade de Deus e",
    "com quanta acomodação Ele falou, tomando providência e cuidado da nossa natureza» (11).",
    "As palavras de Deus com efeito, expressas por línguas humanas, tornaram-se intimamente semelhantes à linguagem humana, como outrora o Verbo do eterno Pai se assemelhou aos homens tomando a carne da fraqueza humana."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_13 = [
    "Portanto, na sacra Escritura, permanecendo firme a verdade e a santidade de Deus, manifesta-se a admirável «condescendência» da eterna sabedoria, «para que nós aprendamos qual inefável benignidade de Deus e", # Diferenças: "sacra" vs "Sagrada", "permanecendo firme" vs "salvas sempre", "para que nós aprendamos" vs "para conhecermos"
    "quanta solicitude ele tenha tido pela nossa natureza» [11].", # Diferenças: "solicitude" vs "acomodação... providência e cuidado", "tenha tido" vs "falou, tomando"
    "As palavras de Deus de facto, expressas com línguas humanas, tornaram-se semelhantes ao falar humano, assim como um tempo o Verbo do eterno Pai, assumindo a carne da humana fraqueza, se fez semelhante aos homens." # Diferenças: "de facto" vs "com efeito", "com" vs "por", "tornaram-se semelhantes ao falar" vs "tornaram-se intimamente semelhantes à linguagem", "assim como um tempo" vs "como outrora", "humana fraqueza" vs "fraqueza humana", "se fez" vs "se assemelhou"
]

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo III, n. 13) ---

contadores_totais_13 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO III, N. 13 (Condescendência de Deus) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_13, SIMULACAO_TRADUCAO_AUTOMATICA_13)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_13[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO III, N. 13 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_13}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo III, n. 13) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_13.keys(), contadores_totais_13.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo III, n. 13', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO III, N. 13 (Condescendência de Deus) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: Portanto, na Sagrada Escritura, salvas sempre a verdade e a santidade de Deus, manifesta-se a admirá...
#   Tradução Auto: Portanto, na sacra Escritura, permanecendo firme a verdade e a santidade de Deus, manifesta-se a adm...
#   Acertos: 24, Erros: 7, Omissões: 5
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: com quanta acomodação Ele falou, tomando providência e cuidado da nossa natureza» (11)....
#   Tradução Auto: quanta solicitude ele tenha tido pela nossa natureza» [11]....
#   Acertos: 5, Erros: 4, Omissões: 7
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
#   Referência: As palavras de Deus com efeito, expressas por línguas humanas, tornaram-se intimamente semelhantes à...
# ...

# %%
# Reutilizando bibliotecas e funções de análise
REFERENCIA_PORTUGUES_PARAGRAFOS_15 = [
    "A «economia» do Antigo Testamento destinava-se sobretudo a preparar, a anunciar profèticamente (cfr. Lc. 24,44; Jo. 5,39; 1 Ped. 1,10) e a simbolizar com várias figuras (cfr. 1 Cor. 10,11) o advento de Cristo, redentor universal, e o do reino messiânico.",
    "Mas os livros do Antigo Testamento, segundo a condição do género humano antes do tempo da salvação estabelecida por Cristo, manifestam a todos o conhecimento de Deus e do homem, e o modo com que Deus justo e misericordioso trata os homens.",
    "Tais livros, apesar de conterem também coisas imperfeitas e transitórias, revelam, contudo, a verdadeira pedagogia divina (1).",
    "Por isso, os fieis devem receber com devoção estes livros que exprimem o vivo sentido de Deus, nos quais se encontram sublimes doutrinas a respeito de Deus, uma sabedoria salutar a respeito da vida humana, bem como admiráveis tesouros de preces, nos quais, finalmente, está latente o mistério da nossa salvação."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_15 = [
    "A economia do Velho Testamento era sobretudo destinada a preparar, a anunciar com profecias (cfr. Lc 24,44; Gv 5,39; 1 Pt 1,10) e a significar com vários tipos (cfr. 1 Cor 10,11) a vinda de Cristo, redentor universal, e do reino messiânico.", # Diferenças: "Velho" vs "Antigo", "profecias" vs "profèticamente", "significar com vários tipos" vs "simbolizar com várias figuras", "a vinda" vs "o advento"
    "Os livros do Velho Testamento, segundo a condição do género humano antes do tempo da salvação efetuada por Cristo, manifestam a todos o conhecimento de Deus e do homem e os modos com que Deus justo e misericordioso trata os homens.", # Diferenças: "Velho" vs "Antigo", "efetuada" vs "estabelecida", "os modos" vs "o modo"
    "Estes livros, embora contenham também coisas imperfeitas e caducas, demonstram todavia uma verdadeira pedagogia divina.", # Diferenças: "Estes" vs "Tais", "embora contenham" vs "apesar de conterem", "caducas" vs "transitórias", "demonstram" vs "revelam", "todavia" vs "contudo"
    "Por isso, os fiéis devem acolher com devoção estes livros, os quais exprimem o vivo sentido de Deus, e nos quais se encontram sublimes doutrinas sobre Deus, salutares ensinamentos sobre a vida do homem e admiráveis tesouros de orações, e finalmente nos quais está escondido o mistério da nossa salvação."
] # Diferenças: "acolher" vs "receber", "os quais" vs "que", "sobre Deus" vs "a respeito de Deus", "salutares ensinamentos sobre a vida do homem" vs "uma sabedoria salutar a respeito da vida humana", "orações" vs "preces", "escondido" vs "latente"

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo IV, n. 15) ---

contadores_totais_15 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO IV, N. 15 (Importância do AT) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_15, SIMULACAO_TRADUCAO_AUTOMATICA_15)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_15[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO IV, N. 15 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_15}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo IV, n. 15) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_15.keys(), contadores_totais_15.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo IV, n. 15', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO IV, N. 15 (Importância do AT) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: A «economia» do Antigo Testamento destinava-se sobretudo a preparar, a anunciar profèticamente (cfr....
#   Tradução Auto: A economia do Velho Testamento era sobretudo destinada a preparar, a anunciar com profecias (cfr. Lc...
#   Acertos: 34, Erros: 11, Omissões: 11
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Mas os livros do Antigo Testamento, segundo a condição do género humano antes do tempo da salvação e...
#   Tradução Auto: Os livros do Velho Testamento, segundo a condição do género humano antes do tempo da salvação efetua...
#   Acertos: 37, Erros: 4, Omissões: 4
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from difflib import SequenceMatcher
import re
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo V, n. 17) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_17 = [
    "A palavra de Deus, que é virtude de Deus para a salvação de todos os crentes (cfr. Rom. 1,16), apresenta-se e manifesta o seu poder dum modo eminente nos escritos do Novo Testamento.",
    "Com efeito, quando chegou a plenitude dos tempos (cfr. Gál. 4,4), o Verbo fez-se carne e habitou entre nós cheio de graça e verdade (cfr. Jo. 1,14).",
    "Cristo estabeleceu o reino de Deus na terra, manifestou com obras e palavras o Pai e a Si mesmo, e levou a cabo a Sua obra com a Sua morte, ressurreição, e gloriosa ascensão, e com o envio do Espírito Santo.",
    "Sendo levantado da terra, atrai todos a si (cfr. Jo. 12,32 gr.), Ele que é o único que tem palavras de vida eterna (cfr. Jo. 6,68).",
    "Este mistério, porém, não foi descoberto a outras gerações como foi agora revelado aos seus santos Apóstolos e aos profetas no Espírito Santo (cfr. Ef. 3, 4-6 gr.) para que pregassem o Evangelho, e despertassem a fé em Jesus Cristo e Senhor, e congregassem a Igreja.",
    "Os escritos do Novo Testamento são um testemunho perene e divino de todas estas coisas."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_17 = [
    "A palavra de Deus, que é potência divina para a salvação de quem crê (cfr. Rm 1,16), se apresenta e manifesta a sua força em modo eminente nos escritos do Novo Testamento.", # Diferenças: "potência divina" vs "virtude de Deus", "quem crê" vs "todos os crentes", "se apresenta" vs "apresenta-se", "sua força" vs "seu poder", "em modo" vs "dum modo"
    "Quando de facto chegou a plenitude dos tempos (cfr. Gal 4,4), o Verbo se fez carne e habitou entre nós pleno de graça e de verdade (cfr. Jo 1,14).", # Diferenças: "de facto" vs "Com efeito", "se fez" vs "fez-se", "pleno" vs "cheio"
    "Cristo estabeleceu o reino de Deus sobre a terra, manifestou com obras e palavras o Pai seu e a si e levou a cumprimento a obra sua com a morte, a ressurreição e a gloriosa ascensão, assim como com o envio do Espírito Santo.", # Diferenças: "sobre a" vs "na", "Pai seu" vs "Pai", "a si" vs "a Si mesmo", "levou a cumprimento" vs "levou a cabo", "obra sua" vs "Sua obra", "assim como com" vs "e com"
    "Elevado da terra, atrai todos a si (cfr. Jo 12,32 gr.), ele que só tem palavras de vida eterna (cfr. Jo 6,68).", # Diferenças: "Elevado" vs "Sendo levantado", "ele que só" vs "Ele que é o único que"
    "Mas este mistério não foi palesado às outras gerações, como agora foi revelado aos seus santos apóstolos seus e aos profetas no Espírito Santo (cfr. Ef 3,4-6 gr.), para que pregassem o Evangelho, suscitasse a fé em Jesus Cristo Senhor e reunissem a Igreja.", # Diferenças: "Mas este mistério" vs "Este mistério, porém", "palesado" vs "descoberto", "agora foi" vs "foi agora", "apóstolos seus" vs "Apóstolos", "suscitasse" vs "despertassem", "reunissem" vs "congregassem"
    "De tudo isto os escritos do Novo Testamento apresentam um testemunho perene e divino."
] # Diferenças: "De tudo isto" vs "Os escritos do Novo Testamento são", "apresentam" vs "um testemunho perene e divino de todas estas coisas" (estrutura totalmente diferente, muitos OMITIDOS)

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo V, n. 17) ---

contadores_totais_17 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO V, N. 17 (Excelência do Novo Testamento) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_17, SIMULACAO_TRADUCAO_AUTOMATICA_17)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_17[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO V, N. 17 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_17}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo V, n. 17) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_17.keys(), contadores_totais_17.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo V, n. 17', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO V, N. 17 (Excelência do Novo Testamento) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: A palavra de Deus, que é virtude de Deus para a salvação de todos os crentes (cfr. Rom. 1,16), apres...
#   Tradução Auto: A palavra de Deus, que é potência divina para a salvação de quem crê (cfr. Rm 1,16), se apresenta e ...
#   Acertos: 23, Erros: 9, Omissões: 11
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Com efeito, quando chegou a plenitude dos tempos (cfr. Gál. 4,4), o Verbo fez-se carne e habitou ent...
#   Tradução Auto: Quando de facto chegou a plenitude dos tempos (cfr. Gal 4,4), o Verbo se fez carne e habitou entre n...
#   Acertos: 25, Erros: 2, Omissões: 2
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...

# %%
from difflib import SequenceMatcher
import re
import matplotlib.pyplot as plt

# --- DADOS DE REFERÊNCIA (Capítulo V, n. 17) ---
REFERENCIA_PORTUGUES_PARAGRAFOS_17 = [
    "A palavra de Deus, que é virtude de Deus para a salvação de todos os crentes (cfr. Rom. 1,16), apresenta-se e manifesta o seu poder dum modo eminente nos escritos do Novo Testamento.",
    "Com efeito, quando chegou a plenitude dos tempos (cfr. Gál. 4,4), o Verbo fez-se carne e habitou entre nós cheio de graça e verdade (cfr. Jo. 1,14).",
    "Cristo estabeleceu o reino de Deus na terra, manifestou com obras e palavras o Pai e a Si mesmo, e levou a cabo a Sua obra com a Sua morte, ressurreição, e gloriosa ascensão, e com o envio do Espírito Santo.",
    "Sendo levantado da terra, atrai todos a si (cfr. Jo. 12,32 gr.), Ele que é o único que tem palavras de vida eterna (cfr. Jo. 6,68).",
    "Este mistério, porém, não foi descoberto a outras gerações como foi agora revelado aos seus santos Apóstolos e aos profetas no Espírito Santo (cfr. Ef. 3, 4-6 gr.) para que pregassem o Evangelho, e despertassem a fé em Jesus Cristo e Senhor, e congregassem a Igreja.",
    "Os escritos do Novo Testamento são um testemunho perene e divino de todas estas coisas."
]

# Tradução Automática Simulada (Sentenças correspondentes, ligeiramente alteradas para fins de comparação)
SIMULACAO_TRADUCAO_AUTOMATICA_17 = [
    "A palavra de Deus, que é potência divina para a salvação de quem crê (cfr. Rm 1,16), se apresenta e manifesta a sua força em modo eminente nos escritos do Novo Testamento.", # Diferenças: "potência divina" vs "virtude de Deus", "quem crê" vs "todos os crentes", "se apresenta" vs "apresenta-se", "sua força" vs "seu poder", "em modo" vs "dum modo"
    "Quando de facto chegou a plenitude dos tempos (cfr. Gal 4,4), o Verbo se fez carne e habitou entre nós pleno de graça e de verdade (cfr. Jo 1,14).", # Diferenças: "de facto" vs "Com efeito", "se fez" vs "fez-se", "pleno" vs "cheio"
    "Cristo estabeleceu o reino de Deus sobre a terra, manifestou com obras e palavras o Pai seu e a si e levou a cumprimento a obra sua com a morte, a ressurreição e a gloriosa ascensão, assim como com o envio do Espírito Santo.", # Diferenças: "sobre a" vs "na", "Pai seu" vs "Pai", "a si" vs "a Si mesmo", "levou a cumprimento" vs "levou a cabo", "obra sua" vs "Sua obra", "assim como com" vs "e com"
    "Elevado da terra, atrai todos a si (cfr. Jo 12,32 gr.), ele que só tem palavras de vida eterna (cfr. Jo 6,68).", # Diferenças: "Elevado" vs "Sendo levantado", "ele que só" vs "Ele que é o único que"
    "Mas este mistério não foi palesado às outras gerações, como agora foi revelado aos seus santos apóstolos seus e aos profetas no Espírito Santo (cfr. Ef 3,4-6 gr.), para que pregassem o Evangelho, suscitasse a fé em Jesus Cristo Senhor e reunissem a Igreja.", # Diferenças: "Mas este mistério" vs "Este mistério, porém", "palesado" vs "descoberto", "agora foi" vs "foi agora", "apóstolos seus" vs "Apóstolos", "suscitasse" vs "despertassem", "reunissem" vs "congregassem"
    "De tudo isto os escritos do Novo Testamento apresentam um testemunho perene e divino."
] # Diferenças: "De tudo isto" vs "Os escritos do Novo Testamento são", "apresentam" vs "um testemunho perene e divino de todas estas coisas" (estrutura totalmente diferente, muitos OMITIDOS)

# --- FUNÇÃO DE ANÁLISE (Mantida) ---
def analisar_palavras_para_grafico(candidata, referencia):
    """Compara duas strings e categoriza palavras como Acerto, Erro ou Extra."""
    candidata_limpa = re.findall(r'\w+', candidata.lower())
    referencia_limpa = re.findall(r'\w+', referencia.lower())

    contadores = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}
    s = SequenceMatcher(None, candidata_limpa, referencia_limpa)

    for tag, i1, i2, j1, j2 in s.get_opcodes():
        if tag == 'equal': contadores["ACERTO"] += (i2 - i1)
        elif tag == 'replace': contadores["ERRO (Substituição)"] += (i2 - i1); contadores["OMITIDO (Exclusão)"] += (j2 - j1)
        elif tag == 'insert': contadores["EXTRA (Inserção)"] += (i2 - i1)
        elif tag == 'delete': contadores["OMITIDO (Exclusão)"] += (j2 - j1)
    return contadores

# --- EXECUÇÃO SENTENÇA POR SENTENÇA (Capítulo V, n. 17) ---

contadores_totais_17 = {"ACERTO": 0, "ERRO (Substituição)": 0, "EXTRA (Inserção)": 0, "OMITIDO (Exclusão)": 0}

print("\n\n### ANÁLISE DO CAPÍTULO V, N. 17 (Excelência do Novo Testamento) ###")
print("="*90)

for i, (ref_paragrafo, auto_paragrafo) in enumerate(zip(REFERENCIA_PORTUGUES_PARAGRAFOS_17, SIMULACAO_TRADUCAO_AUTOMATICA_17)):
    contadores_paragrafo = analisar_palavras_para_grafico(auto_paragrafo, ref_paragrafo)
    for chave, valor in contadores_paragrafo.items():
        contadores_totais_17[chave] += valor

    print(f"**Sentença/Parágrafo {i+1}**")
    print(f"  Referência: {ref_paragrafo[:100]}...")
    print(f"  Tradução Auto: {auto_paragrafo[:100]}...")
    print(f"  Acertos: {contadores_paragrafo['ACERTO']}, Erros: {contadores_paragrafo['ERRO (Substituição)']}, Omissões: {contadores_paragrafo['OMITIDO (Exclusão)']}")
    print("-" * 90)

print(f"\n✅ ANÁLISE TOTAL DO CAPÍTULO V, N. 17 CONCLUÍDA")
print(f"TOTAIS FINAIS DE PALAVRAS (Tokens): {contadores_totais_17}")

# --- GERAÇÃO DO GRÁFICO FINAL (Capítulo V, n. 17) ---
plt.figure(figsize=(10, 6))
barras = plt.bar(contadores_totais_17.keys(), contadores_totais_17.values(), color=['#4CAF50', '#FFC107', '#2196F3', '#F44336'])
plt.title('Comparação Total da Tradução do Capítulo V, n. 17', fontsize=14)
plt.xlabel('Status da Palavra na Comparação', fontsize=12)
plt.ylabel('Contagem de Palavras (Tokens)', fontsize=12)
for bar in barras:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ### ANÁLISE DO CAPÍTULO V, N. 17 (Excelência do Novo Testamento) ###
# ...
# **Sentença/Parágrafo 1**
#   Referência: A palavra de Deus, que é virtude de Deus para a salvação de todos os crentes (cfr. Rom. 1,16), apres...
#   Tradução Auto: A palavra de Deus, que é potência divina para a salvação de quem crê (cfr. Rm 1,16), se apresenta e ...
#   Acertos: 23, Erros: 9, Omissões: 11
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 2**
#   Referência: Com efeito, quando chegou a plenitude dos tempos (cfr. Gál. 4,4), o Verbo fez-se carne e habitou ent...
#   Tradução Auto: Quando de facto chegou a plenitude dos tempos (cfr. Gal 4,4), o Verbo se fez carne e habitou entre n...
#   Acertos: 25, Erros: 2, Omissões: 2
# ------------------------------------------------------------------------------------------
# **Sentença/Parágrafo 3**
# ...
